# %%
import pandas as pd
from bs4 import BeautifulSoup
import os
import re
from natsort import natsorted

# %%
def parse_val(text):
    if not text: return 0
    text = text.upper().strip()
    
    # Extract numeric part and multiplier
    match = re.search(r'(\d+\.?\d*)([KMB]?)', text)
    if not match: return 0
    
    number = float(match.group(1))
    multiplier = match.group(2)
    
    if multiplier == 'K': number *= 1000
    elif multiplier == 'M': number *= 1000000
    elif multiplier == 'B': number *= 1000000000
    
    return int(number)

# %%
def parse_reaction_count(story):
    # Case 1: "Person A, Person B and 18K others"
    node_others = story.find('span', string=lambda x: x and 'others' in x.lower())
    if node_others:
        text = node_others.get_text(strip=True)
        # Count names before 'and'
        names_part = text.split(' and ')[0]
        individual_names_count = len(names_part.split(',')) if ',' in names_part or ' ' in names_part else 1
        return parse_val(text) + individual_names_count

    # Case 2: "All reactions: 2.5K" (Your new snippet)
    # Look for the 'All reactions' text or the specific class used for shorthand counts
    all_reactions_btn = story.find('div', string=re.compile("All reactions", re.I))
    if all_reactions_btn:
        # Find the sibling/parent span that contains the count (class xt0b8zv from your snippet)
        count_node = all_reactions_btn.find_parent().find('span', class_='xt0b8zv')
        if count_node:
            return parse_val(count_node.get_text(strip=True))

    return 0

# %%
def parse_html(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        html_content = f.read()

    soup = BeautifulSoup(html_content, 'html.parser')

    stories = soup.select('div[data-focus="feed_story"]')

    data_list = []


    for story in stories:
        # --- Content ---
        content_node = (story.find('span', {'data-ad-rendering-role': 'description'}) or
                        story.find('div', {'data-ad-comet-preview': 'message'}) or 
                        story.find('div', {'data-ad-preview': 'message'}))
        content = content_node.get_text(strip=True) if content_node else "N/A"

        # --- Reactions ---
        reaction_count = parse_reaction_count(story)

        # --- Comments ---
        comment_node = story.find('span', string=lambda x: x and 'comments' in x.lower())
        comment_text = comment_node.get_text(strip=True) if comment_node else "0"
        comments_count = ''.join(filter(str.isdigit, comment_text)) or "0"

        # --- Shares ---
        share_node = story.find('span', string=lambda x: x and 'share' in x.lower())
        share_text = share_node.get_text(strip=True) if share_node else "0"
        shares_count = ''.join(filter(str.isdigit, share_text)) or "0"

        print (content)
        print (reaction_count)
        print (comments_count)
        print (shares_count)
        print ('\n')
        return {content, reaction_count, comments_count, shares_count}

# %%
directory_path = '../harvested/'
entries = os.listdir(directory_path)

for e in entries:
    files = natsorted(os.listdir(os.path.join(directory_path, e)))
    
    print(e)
    for f in files:
        relative_path = os.path.join(directory_path, e, f)
        print(relative_path)
        parse_html(relative_path)
# Out:
# nebresultandnews0
# ../harvested/nebresultandnews0/[0].html
# एमालेको झण्डा जलाएको विरोधमा युवा संघले देशभर राँ!के जु!लुस निकाल्ने भएको छ।
# 3100
# 201
# 8
#
#
# ../harvested/nebresultandnews0/[1].html
# Stay Healthy: काठमाडौं उपत्यकामा अत्यधिक वायु प्रदूषण बढेको छ। बिनाकाम घर बाहिर नजानुहोला, जानैपरे अनिवार्य मास्क लगाउने गरौं !
# 1200
# 28
# 2
#
#
# ../harvested/nebresultandnews0/[2].html
# सर्वोच्च अदालतले संसद विघटनविरुद्धको रिटलाई चुनावको भोलिपल्ट अर्थात् फागुन २२ गते तारेख दिएको छ।
# 5100
# 145
# 32
#
#
# ../harvested/nebresultandnews0/[3].html
# Balen Shah को नागरिकता रद्द गर्न माग गर्दै Yubaraj Saphal ले गृह मन्त्रालयमा उजुरी दिएका छन्।
# 9600
# 590
# 37
#
#
# ../harvested/nebresultandnews0/[4].html
# मनका धनी: TikToker Coolboyyy ले क!लेजोका बि!रामीलाई उपचारका लागि १ ला!ख रुपै!याँ सह!योग गरेका छन्।
# 7400
# 79
# 2
#
#
# ../harvested/nebresultandnews0/[5].html
# गरिबीलाइ रोकेन चुनाबले: गएको 7 महिनामा 4 लाख 72 हजार नेपालीले रोज’गारीका लागि नेपाल छोडेका छन।
# 5500
# 138
# 28
#
#
# ../harvested/nebresultandnews0/[6].html
# Kathmandu ma clz padhne kt lai pixa garera jiskaune ani hairan banaune ek jana 25 years old male lai police le arre'st gareko chha.
# 2300
# 152
# 1
#
#
# ../harvested/nebresultandnews0/[7].html
# आज शुक्रबार ! भगवान हनुमानको आशिर्वादले तपाईंको दिन शुभ रहोस् !Pic. Dibas Neupane
# 9300
# 220
# 28
#
#
# ../harvested/nebresultandnews0/[8].html
# बिहान उठ्ने बित्तिकै हिमाल देख्न पाइयोस्: Good Morning! We are from Kanchanjanga Himal, Nepal.Pic. Sabin Subedi
# 3200
# 25
# 1
#
#
# ../harvested/nebresultandnews0/[9].html
# ढिलो चाडो होला तर, सत्यको एकदिन जित हुन्छ।#शुभरात्री
# 2900
# 82
# 25
#
#
# ../harvested/nebresultandnews0/[10].html
# आहा: Beautiful Night View of Bharatpur, Chitwan NepalPic. Sulakshya Pokhrel
# 2200
# 31
# 3
#
#
# ../harvested/nebresultandnews0/[11].html
# विश्वकप जित्छ कि क्या हो: जारी विश्वकपमा अपराजित Zimbabwe ले आज पनि Sri Lanka लाई 6 विकेटले पराजित गरेको छ।
# 4800
# 45
# 6
#
#
# ../harvested/nebresultandnews0/[12].html
# सरकारले निर्वाचन प्रचार प्रसारमा हिड्दा उम्मेदवारहरूले छत 'sunroof' खोलेर हिंड्न मिल्ने सवारी साधनको प्रयोग गर्न नपाउने निर्णय गरेको छ।
# 8200
# 256
# 32
#
#
# ../harvested/nebresultandnews0/[13].html
# क्रीकेटमा उदाउँदै जुनियर Sandeep: NPL जस्तै सबै प्रदेशलाई समेटेर काठमाडौंमा सम्पन्न PABSON U-15 National League मा उत्कृष्ट all round प्रदर्शन गरेका Sandeep Saud, Player of the Tournament बनेका छन्। आगामी दिनहरुमा प्रगतिको शुभकामना !
# 2800
# 42
# 7
#
#
# ../harvested/nebresultandnews0/[14].html
# Shocking: एउटा AI event मा एक Indian University ले China मा बनेको robotic dog लाई आफ्नै University ले बनाएको दाबी गरेपछि social media मा विवाद भएको छ।
# 2900
# 88
# 1
#
#
# ../harvested/nebresultandnews0/[15].html
# Rastriya Swatantra Party ले आफ्नो चुनावी घोषणापत्र सार्वजनिक गरेको छ।More Details in comments.
# 7700
# 191
# 10
#
#
# ../harvested/nebresultandnews0/[16].html
# Yemale ले आफ्नो चुनावी घोषणा पत्र सार्वजनिक गरेको छ।More details in comment.
# 2500
# 320
# 7
#
#
# ../harvested/nebresultandnews0/[17].html
# Yemale ले 18-28 age का युवालाई एक वर्षसम्म हरेक महिना 10 GB Internet Data Free मै दिने बताएको छ।
# 16000
# 21
# 85
#
#
# ../harvested/nebresultandnews0/[18].html
# Instagram ले Instagram official account बाट Nepali Vlogger Surakshya KC काे video हालेकाे छ साथै उनलाई follow समेत गरेको छ।
# 8500
# 160
# 5
#
#
# ../harvested/nebresultandnews0/[19].html
# उहाँ एमाले नेताको भोट माग्ने तरिका कस्तो लाग्दै छ?
# 3000
# 222
# 11
#
#
# ../harvested/nebresultandnews0/[20].html
# निर्वाचनमा खटिएका निर्वाचन (म्यादी) प्रहरीले स्वदेशी उत्पादन गोल्डस्टार जुत्ता र भारतीय बेतको लट्ठी प्रयोग गर्ने छन्।
# 4300
# 104
# 5
#
#
# ../harvested/nebresultandnews0/[21].html
# नेपालमा चुनाव आउन अब ठ्याक्कै १४ दिन बाँकी रहेको छ। Vote हाल्न कत्तिको excited हुनुहुन्छ?
# 3200
# 121
# 0
#
#
# kantipurtvhd
# ../harvested/kantipurtvhd/[0].html
# पाल्पामा कक्षा ६ मा पढ्ने र विद्यालय नजाने १० वर्षका २ हजार ४३ जना किशोरीलाई पाठेघरको मुखको क्यान्सरविरूद्धको एचपीभी खोप लगाइएको
# 0
# 0
# 0
#
#
# ../harvested/kantipurtvhd/[1].html
# सुदूरपश्चिम, कर्णाली र कोशी प्रदेशमा प्रतिनिधि सभा निर्वाचनको मतपत्र ढुवानीको काम सम्पन्न भएको छ ।
# 45
# 0
# 0
#
#
# ../harvested/kantipurtvhd/[2].html
# प्रतिनिधि सभा विघटनविरूद्धको रिट निवेदनमा सर्वोच्च अदालतले यही फागुन २२ गते साधारण तारिखका लागि मिति तोकेको छ ।
# 86
# 15
# 1
#
#
# ../harvested/kantipurtvhd/[3].html
# राष्ट्रिय स्वतन्त्र पार्टी-रास्वपाका सभापति रवि लामिछानेले यसपटक सरकार चलाउने जिम्मा आफ्नो पार्टीले लिने उल्लेख गर्दै अन्य दलहरूलाई प्रतिपक्षमा बसेर खबरदारी गर्न आग्रह गर्नुभएको छ ।
# 145
# 39
# 0
#
#
# ../harvested/kantipurtvhd/[4].html
# निर्वाचन आयोगले बैंक खाता खोल्ने कामका ढिलाइ नगर्न प्रतिनिधि सभाका उम्मेदवारहरूलाई ताकेता गरेको छ ।विस्तृत:https://kantipurtv.com/news/2026/02/20/1771583229.html
#  #NepalElection #Kathmandu #ElectionCommission #SitaPunShrees #TransparentElections
# 49
# 0
# 0
#
#
# ../harvested/kantipurtvhd/[5].html
# नेपाल उद्योग वाणिज्य महासंघका उपाध्यक्ष हेमराज ढकालले होटल उद्योगमा भएको लगानीको सुरक्षण राज्यले गर्नुपर्ने बताउनुभएको छ ।
# 38
# 0
# 2
#
#
# ../harvested/kantipurtvhd/[6].html
# लमजुङको दोर्दी गाउँपालिका-१, भारते ढिन गाउँमा आफैंले चलाएको ट्रयाक्टरले च्यापिएर शुक्रबार चालकको घटनास्थलमै मृत्यु भएको छ ।विस्तृत:https://kantipurtv.com/others/2026/02/20/1771577232.html
#  #LamjungAccident #SherBahadurTamang #TractorAccident #NepalRoadSafety #Nuwakot
# 21
# 0
# 0
#
#
# ../harvested/kantipurtvhd/[7].html
# नागरिक लगानी कोषले मधेश प्रदेशको राजधानी जनकपुरधाममा पनि आफ्नो शाखा विस्तार गरेको छ ।
# 38
# 0
# 1
#
#
# ../harvested/kantipurtvhd/[8].html
# मतदानको मिति नजिकिँदै जाँदा धादिङमा पनि निर्वाचनको चहलपहल बढेको छ ।विस्तृत:https://kantipurtv.com/news/2026/02/20/1771575667.html
#  #DhadingElection #NepalPolitics #RameshDhamala #DhanBahadurGhale #NepaliCongress
# 49
# 0
# 0
#
#
# ../harvested/kantipurtvhd/[9].html
# अर्थमन्त्री रामेश्वर खनालले फागुन २१ मा चुनाव हुँदैन कि भन्ने संशय हटेको बताउनुभएको छ ।
# 98
# 0
# 1
#
#
# ../harvested/kantipurtvhd/[10].html
# मानव अधिकार आयोगका अध्यक्ष तपबहादुर मगरले समाजमा विद्यमान विभेद र बहिष्करण अन्त्य गर्नुपर्नेमा जोड दिनुभएको छ ।
# 13
# 0
# 0
#
#
# ../harvested/kantipurtvhd/[11].html
# लमजुङको दोर्दी गाउँपालिका-१, भारते ढिन गाउँमा आफैंले चलाएको ट्रयाक्टरले च्यापिएर शुक्रबार चालकको घटनास्थलमै मृत्यु भएको छ ।
# 23
# 0
# 0
#
#
# ../harvested/kantipurtvhd/[12].html
# प्रतिनिधि सभा निर्वाचनका लागि १३ दिन बाँकी रहेको छ ।
# 36
# 0
# 0
#
#
# ../harvested/kantipurtvhd/[13].html
# भूमि व्यवस्था, सहकारी तथा गरिबी निवारणमन्त्री प्रा.डा. कुमार इङनामले निर्माणाधिन नयाँ संघीय संसद् भवनको काम चैत १ गतेभित्र सम्पन्न गरी हस्तान्तरण गर्न निर्देशन दिनुभएको छ ।
# 40
# 0
# 0
#
#
# officialroutineofnepalbanda
# ../harvested/officialroutineofnepalbanda/[0].html
# यहि कतै बिलाउन मन छ: Beautiful Sunset view as seen from Sauraha, Chitwan .Photo: Sushil Koirala
# 3400
# 68
# 14
#
#
# ../harvested/officialroutineofnepalbanda/[1].html
# राम्रो पहल: Nepal’s first IT college LBEF has signed a scholarship agreement with the Nepal Police Wives Association to provide 50+ ICT scholarships for Nepal Police families, including 7 students from all provinces receiving 100 percent fee waiver (zero fee) for higher education.#CollabAdFor more details:https://lbef.org/scholarship.php
# 873
# 17
# 5
#
#
# ../harvested/officialroutineofnepalbanda/[2].html
# सोलुखुम्बुबाट उम्मेदवारी दिएका ४२ वर्षीय युवा नेता असिम राई,   २०७४ र २०७९ सालको स्थानीय तह निर्वाचनमा दूधकोशी गाउँपालिकाको अध्यक्ष पदमा निर्वाचित भइसकेका अनुभवी जनप्रतिनिधि हुन्। राईले स्थानीय तहमा रहँदा  ५० शैय्याको सुविधासम्पन्न अस्पताल निर्माणमा सहयोग गर्नुका साथै सांस्कृतिक तथा धार्मिक स्थल संरक्षण लगायत सामाजिक क्षेत्रको लागि ठूलो भूमिका खेलेका थिए ।
# 4100
# 305
# 61
#
#
# ../harvested/officialroutineofnepalbanda/[3].html
# PM Sushila Karki congratulates graduated Students in PU Convocation & says, "आज प्राप्त गर्नुभएको प्रमाणपत्र रोजगारीको आधार मात्र होइन, यो नेपाली समाज र राष्ट्रका जटिल समस्या पहिचान गरी तिनका दीर्घकालीन समाधान खोज्न सक्ने क्षमताको द्योतक बन्नुपर्छ । आजको युगमा युवा नै अबका राजनेता, प्रशासक, नीति–निर्माता र समाज रूपान्तरणका अभियन्ता हुन् । त्यसैले तपाईंहरूले कस्तो भविष्यको परिकल्पना गर्नुभएको छ, त्यसको जग आजैबाट मजबुत बनाउनुपर्नेछ ।"
# 4800
# 82
# 4
#
#
# ../harvested/officialroutineofnepalbanda/[4].html
# भिरकोट, स्याङ्जाका ७८ वर्षीय रामप्रसाद खनाल र टीका कुमारी खनालले घर परिवारको उपस्थितिमा विवाहको ६० औं वार्षिकोत्सब मनाउनु भएको छ ।#TogetherForever
#
# Pic. Dr. Sukriti Acharya
# 5000
# 109
# 3
#
#
# ../harvested/officialroutineofnepalbanda/[5].html
# प्रधानमन्त्री सुशीला कार्कीले मुक्तिनाथ मन्दिरको दर्शन गर्नु भएको छ!
# 21000
# 223
# 12
#
#
# ../harvested/officialroutineofnepalbanda/[6].html
# Amazing art of Lord Ganesh.Photo. Razes Arts
# 11000
# 128
# 15
#
#
# ../harvested/officialroutineofnepalbanda/[7].html
# Dr. Nicholas Bhusal dressing the wo'und of inju"red GenZ youth Shantanu Dhakal. #News
# 15000
# 178
# 46
#
#
# ../harvested/officialroutineofnepalbanda/[8].html
# Nepali actress Niti Shah gets married with Yachnit Rana.#Congrats
# 20000
# 313
# 12
#
#
# ../harvested/officialroutineofnepalbanda/[9].html
# सगरमाथालाई पहिलो पटक नजिकबाट देख्न पाउँदा भावुक हुँदै पर्यटक ।Pic. Captain Andy
# 30000
# 151
# 43
#
#
# ../harvested/officialroutineofnepalbanda/[10].html
# Young Inspiration: ढल्केबर, धनुषाका १९ वर्षीय कुशल घिमिरेले +२ मा Hotel Management पढ्दै होटलमा ४ महिना kitchen helper को रुपमा काम गरे अनि त्यो काम छोडेर bakery मा २ महिना delivery को काम गर्दै गर्दा chef ले बनाएको हेर्दै केक लगायतका परिकार पनि बनाउन सिके । त्यसपछि आफैं केहि गर्ने सोचेर उनी विगत केहि समय देखि आफ्नै घरको सानो कोठामा केकका परिकारहरु बनाउदै, customer को demand अनुसार surprise पनि दिदै दैनिक राम्रो आम्दानी गर्दै आइरहेका छन् । बिहान कलेज पढ्न जाने र दिउँसोको खाली समयमा घरमै bakery को काम गर्ने उनी भन्छन्, "सानो कुराबाट सुरुवात गरेर पनि सफलता हासिल गर्न सकिन्छ ।"Pic & Story: @roshangautam7409
# 4400
# 132
# 26
#
#
# ../harvested/officialroutineofnepalbanda/[11].html
# Interesting: Leader Madhav Kumar Nepal as seen joining Tiktok LIVE & discussing about the election.
# 17001
# 646
# 29
#
#
# ../harvested/officialroutineofnepalbanda/[12].html
# Harka Sampang says "आउनुन बालेन दाई आउनु सम्हाल्दिनु देश भन्दाखेरि कहाँ गयो, गयो है । महिनौं, महिनौं लुकेर बसेर हिजोआज चाहिँ प्रधानमन्त्री बन्छु भनेर चाहिँ नि एक हजार पुलिससँग हिडेको देख्छु । मैले बारम्बार भनेको छु, अहिलेको गृहमन्त्री र अहिलेको IGP को स्पष्टीकरण लिन्छ श्रम संस्कृति पार्टीले है । भयभरको पुलिस चाहिँ बालेनको अघिपछि किन पठाको ? हामी पनि त उमेदवार हो । खोई त हाम्रो त छैन त्यस्तो security."
# 31000
# 34
# 68
#
#
# ../harvested/officialroutineofnepalbanda/[13].html
# Mahabir Pun after getting support from local people of Myagdi says, "अचम्मको कुरा हेर्नुहोस् - भोट माग्न गाउँ गाँउ जाँदा मतदाताहरुले मलाई चुनाव खर्च भनेर पै"सा दिइ रहेकाछन्। उमेदवारले पै"सा बाँडेर भोट माग्छन् भन्ने सुनिन्छ। मलाई ता उल्टै दिईरहेका छन। सबै हिसाव किताब प्रष्ट संग सार्वजनिक गर्नेछु। पै"सामात्र होइन, धेरै जसो गाउँ गाउँमा खान बस्न पनि स्पोन्सर गरेका छन्।"
# 17000
# 395
# 103
#
#
# ../harvested/officialroutineofnepalbanda/[14].html
# Instagram has posted a video of Nepali moto vlogger Surakshya KC in its official Insta account & started following her too.
# 36001
# 398
# 24
#
#
# ../harvested/officialroutineofnepalbanda/[15].html
# Footballer Cristiano Ronaldo is 38 goals away from reaching 1,000 goals in his career.#GOAT
# 16001
# 353
# 37
#
#
# ../harvested/officialroutineofnepalbanda/[16].html
# Friday Morning & Statue of Lord Hanuman Ji at BiratnagarPhoto. Bibek Poudel
# 19001
# 442
# 88
#
#
# ../harvested/officialroutineofnepalbanda/[17].html
# जित्ने वा हार्ने चिन्ता नगरी सबै कुरामा आफ्नो इमानदारीपूर्वक प्रयास गर्नुहोस् ।अध्ययन गर्ने कुरा होस् वा खेल्ने कुरा होस् वा अरुलाई मद्दत गर्ने कुरा होस्।#GoodnightPeace
# 4101
# 214
# 53
#
#
# ../harvested/officialroutineofnepalbanda/[18].html
# Beautiful Night View Of Kathmandu Valley as seen from Nagarjun area.Pic. @shreedeep_paudel
# 4801
# 58
# 2
#
#
# ../harvested/officialroutineofnepalbanda/[19].html
# Our extra dose of News for today.
# 1001
# 13
# 2
