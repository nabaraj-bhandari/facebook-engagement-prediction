# %%
import pandas as pd
from bs4 import BeautifulSoup
import os
import re
from natsort import natsorted

# %%
def parse_html(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        html_content = f.read()

    soup = BeautifulSoup(html_content, 'html.parser')

    stories = soup.select('div[data-focus="feed_story"]')

    data_list = []


    for story in stories:
        print ()
        print (reaction_count)
        print ('\n')
        return {content, reaction_count, comments_count, shares_count}

# %%
parse_html("../harvested/officialroutineofnepalbanda/[15].html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 parse_html("../harvested/officialroutineofnepalbanda/[15].html")
#
# Cell In[9], line 13, in parse_html(file_path)
#       9 data_list = []
#      12 for story in stories:
# ---> 13     print (content)
#      14     print (reaction_count)
#      15     print ('\n')
#
# NameError: name 'content' is not defined
